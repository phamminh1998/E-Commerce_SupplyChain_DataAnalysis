# %% [markdown]
# <h1><b>Splitting 1 CSV File into Multiple CSV Files (By Column)</h1></b>

# %%
# Loading the required functions
import pandas as pd
import os
import numpy as np

# %%
file_path = os.path.expanduser(r'~\Documents\GitHub\E-Commerce_SupplyChain_DataAnalysis\data\interim\cleaned_data.csv')
# Import the cleaned data with specified data types
clean_df = pd.read_csv(file_path, dtype={
    'customer_zipcode': str,
    'order_zipcode': str
})

# %% [markdown]
# DATABASE STRUCTURE
# ------------------
#
# The data schema will contain 6 dimension tables and 1 fact table for order information
# 1) dim_location: Locations (combining customer and order information)
# 2) dim_customer: Information related to customers
# 3) dim_product: Details about products
# 4) dim_category: Product category
# 5) dim_date: Dates for various events (order, shipping)
# 6) dim_order_status: Order statuses
# 7) dim_market: Market information
# 8) order

# %%
## dim_location table
# Extract the required columns for customer and order locations
dim_location = clean_df[['order_city', 'order_state', 'order_zipcode', 'order_region', 'order_country','market']].copy()

# Drop duplicates to ensure unique locations then Generate a unique location_id
dim_location = dim_location.drop_duplicates().reset_index(drop=True)
dim_location['location_id'] = range(1, len(dim_location) + 1)
display(dim_location)
# Out:
#        order_city      order_state order_zipcode    order_region  \
# 0          Bekasi  Java Occidental           NaN  Southeast Asia
# 1         Bikaner         Rajastán           NaN      South Asia
# 2      Townsville       Queensland           NaN         Oceania
# 3       Toowoomba       Queensland           NaN         Oceania
# 4       Guangzhou        Guangdong           NaN    Eastern Asia
# ...           ...              ...           ...             ...
# 3795      Urganch          Khorezm           NaN    Central Asia
# 3796  Pico Rivera       California         90660     West of USA
# 3797     Tongling            Anhui           NaN    Eastern Asia
# 3798      Liuyang            Hunan           NaN    Eastern Asia
# 3799       Nashua  Nuevo Hampshire          3060     East of USA
#
#       order_country         market  location_id
# 0         Indonesia   Pacific Asia            1
# 1             India   Pacific Asia            2
# 2         Australia   Pacific Asia            3
# 3         Australia   Pacific Asia            4
# 4             China   Pacific Asia            5
# ...             ...            ...          ...
# 3795     Uzbekistan   Pacific Asia         3796
# 3796  United States  North America         3797
# 3797          China   Pacific Asia         3798
# 3798          China   Pacific Asia         3799
# 3799  United States  North America         3800
#
# [3800 rows x 7 columns]

# %%
# dim_customer Table
dim_customer = clean_df.filter(regex='^customer_').copy()
dim_customer = dim_customer.drop_duplicates().reset_index(drop=True)

display(dim_customer)
# Out:
#       customer_city customer_email customer_fname  customer_id customer_lname  \
# 0            Caguas      XXXXXXXXX          Cally        20755       Holloway
# 1            Caguas      XXXXXXXXX          Irene        19492           Luna
# 2          San Jose      XXXXXXXXX        Gillian        19491      Maldonado
# 3       Los Angeles      XXXXXXXXX           Tana        19490           Tate
# 4            Caguas      XXXXXXXXX           Orli        19489      Hendricks
# ...             ...            ...            ...          ...            ...
# 20647        Caguas      XXXXXXXXX          Diana        18586           Tran
# 20648        Caguas      XXXXXXXXX          Anika        16322      Davenport
# 20649        Caguas      XXXXXXXXX           Yuri        18579          Smith
# 20650        Caguas      XXXXXXXXX       Hyacinth        16244           Witt
# 20651        Caguas      XXXXXXXXX           Mary         2677          Davis
#
#       customer_password customer_segment customer_state  \
# 0             XXXXXXXXX         Consumer             PR
# 1             XXXXXXXXX         Consumer             PR
# 2             XXXXXXXXX         Consumer             CA
# 3             XXXXXXXXX      Home Office             CA
# 4             XXXXXXXXX        Corporate             PR
# ...                 ...              ...            ...
# 20647         XXXXXXXXX      Home Office             PR
# 20648         XXXXXXXXX      Home Office             PR
# 20649         XXXXXXXXX      Home Office             PR
# 20650         XXXXXXXXX      Home Office             PR
# 20651         XXXXXXXXX      Home Office             PR
#
#                 customer_street customer_zipcode
# 0      5365 Noble Nectar Island              725
# 1              2679 Rustic Loop              725
# 2          8510 Round Bear Gate            95125
# 3               3200 Amber Bend            90027
# 4      8671 Iron Anchor Corners              725
# ...                         ...              ...
# 20647      1802 Broad Carrefour              725
# 20648   8284 Colonial Gate Path              725
# 20649         2248 Heather Mews              725
# 20650  7247 Honey Prairie Field              725
# 20651         6422 Sleepy Swale              725
#
# [20652 rows x 10 columns]

# %%
# dim_category Table
dim_category = clean_df[['category_id', 'category_name']]
dim_category = dim_category.drop_duplicates().sort_values(by='category_id').reset_index(drop=True)
display(dim_category)
# Out:
#     category_id         category_name
# 0             2                Soccer
# 1             3   Baseball & Softball
# 2             4            Basketball
# 3             5              Lacrosse
# 4             6      Tennis & Racquet
# 5             7                Hockey
# 6             9      Cardio Equipment
# 7            10     Strength Training
# 8            11   Fitness Accessories
# 9            12          Boxing & MMA
# 10           13           Electronics
# 11           16       As Seen on  TV!
# 12           17                Cleats
# 13           18        Men's Footwear
# 14           24       Women's Apparel
# 15           26        Girls' Apparel
# 16           29         Shop By Sport
# 17           30      Men's Golf Clubs
# 18           31    Women's Golf Clubs
# 19           32          Golf Apparel
# 20           33            Golf Shoes
# 21           34     Golf Bags & Carts
# 22           35           Golf Gloves
# 23           36            Golf Balls
# 24           37           Electronics
# 25           38      Kids' Golf Clubs
# 26           40           Accessories
# 27           41              Trade-In
# 28           43      Camping & Hiking
# 29           44    Hunting & Shooting
# 30           45               Fishing
# 31           46  Indoor/Outdoor Games
# 32           48          Water Sports
# 33           59                 Books
# 34           60                  Baby
# 35           61                   CDs
# 36           62               Cameras
# 37           63   Children's Clothing
# 38           64             Computers
# 39           65  Consumer Electronics
# 40           66                Crafts
# 41           67                  DVDs
# 42           68                Garden
# 43           69     Health and Beauty
# 44           70        Men's Clothing
# 45           71                 Music
# 46           72          Pet Supplies
# 47           73        Sporting Goods
# 48           74                  Toys
# 49           75           Video Games
# 50           76      Women's Clothing

# %%
# dim_product Table
dim_product = clean_df.filter(regex='^product_').copy()
dim_product = dim_product.drop_duplicates().reset_index(drop=True).sort_values(by='product_card_id')
display(dim_product)
# Out:
#      product_card_id  product_category_id  \
# 87                19                    2
# 22                24                    2
# 83                35                    3
# 51                37                    3
# 14                44                    3
# ..               ...                  ...
# 75              1359                   72
# 0               1360                   73
# 114             1361                   74
# 79              1362                   75
# 29              1363                   76
#
#                                          product_image  \
# 87   http://images.acmesports.sports/Nike+Men%27s+F...
# 22   http://images.acmesports.sports/Elevation+Trai...
# 83   http://images.acmesports.sports/adidas+Brazuca...
# 51   http://images.acmesports.sports/adidas+Kids%27...
# 14   http://images.acmesports.sports/adidas+Men%27s...
# ..                                                 ...
# 75   http://images.acmesports.sports/Adult+dog+supp...
# 0          http://images.acmesports.sports/Smart+watch
# 114               http://images.acmesports.sports/Toys
# 79   http://images.acmesports.sports/Fighting+video...
# 29      http://images.acmesports.sports/Summer+dresses
#
#                                    product_name  product_price
# 87      Nike Men's Fingertrap Max Training Shoe     124.989998
# 22                  Elevation Training Mask 2.0      79.989998
# 83      adidas Brazuca 2014 Official Match Ball     159.990005
# 51        adidas Kids' F5 Messi FG Soccer Cleat      34.990002
# 14   adidas Men's F10 Messi TRX FG Soccer Cleat      59.990002
# ..                                          ...            ...
# 75                           Adult dog supplies      84.400002
# 0                                   Smart watch     327.750000
# 114                                        Toys      11.540000
# 79                         Fighting video games      39.750000
# 29                               Summer dresses     215.820007
#
# [118 rows x 5 columns]

# %%
# dim_department Table
dim_department = clean_df[['department_id', 'department_name']]
dim_department = dim_department.drop_duplicates().sort_values(by='department_id').reset_index(drop=True)    
display(dim_department)
# Out:
#     department_id    department_name
# 0               2            Fitness
# 1               3           Footwear
# 2               4            Apparel
# 3               5               Golf
# 4               6           Outdoors
# 5               7           Fan Shop
# 6               8          Book Shop
# 7               9         Discs Shop
# 8              10         Technology
# 9              11           Pet Shop
# 10             12  Health and Beauty

# %%
# Orders Table
orders_fact = clean_df.drop(columns=['category_id','category_name', 'department_name','product_name','product_image','product_card_id','product_category_id','product_price','order_item_product_price'])
orders_fact = pd.merge(orders_fact, dim_location, how='left',
                       on=['order_city','order_zipcode','order_state','order_country','order_region','market'])
orders_fact = orders_fact.drop(columns=['order_city','order_state','order_zipcode','order_country','order_region','market'])
orders_fact = orders_fact.drop(columns=['customer_id','customer_city','customer_state','customer_zipcode','customer_fname','customer_lname','customer_segment','customer_street','customer_email','customer_password'])
orders_fact = orders_fact.drop_duplicates().sort_values(by='order_id').reset_index(drop=True)

display(orders_fact)
# Out:
#             type  days_for_shipping_(real)  days_for_shipment_(scheduled)  \
# 0           CASH                         2                              4
# 1        PAYMENT                         3                              4
# 2        PAYMENT                         3                              4
# 3        PAYMENT                         3                              4
# 4           CASH                         5                              4
# ...          ...                       ...                            ...
# 180514  TRANSFER                         6                              4
# 180515     DEBIT                         2                              4
# 180516     DEBIT                         3                              4
# 180517   PAYMENT                         4                              4
# 180518      CASH                         1                              0
#
#         benefit_per_order  sales_per_customer   delivery_status  \
# 0               88.790001          239.979996  Advance shipping
# 1               36.470001          107.889999  Advance shipping
# 2               68.250000          227.500000  Advance shipping
# 3               91.180000          193.990005  Advance shipping
# 4               33.590000          159.940002     Late delivery
# ...                   ...                 ...               ...
# 180514        -107.959999          161.869995     Late delivery
# 180515        -126.559998          172.660004  Advance shipping
# 180516          91.250000          314.640015  Advance shipping
# 180517           1.530000           10.910000  Shipping on time
# 180518           9.790000           34.980000     Late delivery
#
#         late_delivery_risk  department_id   latitude  longitude  ...  \
# 0                        0              7  35.776661 -81.362625  ...
# 1                        0              4  41.832722 -87.980484  ...
# 2                        0              5  41.832722 -87.980484  ...
# 3                        0              7  41.832722 -87.980484  ...
# 4                        1              7  29.520010 -98.637413  ...
# ...                    ...            ...        ...        ...  ...
# 180514                   1              4  18.273024 -66.037056  ...
# 180515                   0              4  41.608639 -88.202042  ...
# 180516                   0              2  18.251453 -66.037056  ...
# 180517                   0              7  41.830791 -87.802979  ...
# 180518                   1              9  25.860285 -80.197342  ...
#
#         order_item_id order_item_profit_ratio  order_item_quantity  \
# 0                   1                    0.37                    1
# 1                   4                    0.34                    1
# 2                   3                    0.30                    5
# 3                   2                    0.47                    1
# 4                   8                    0.21                    4
# ...               ...                     ...                  ...
# 180514         180515                   -0.67                    1
# 180515         180516                   -0.73                    1
# 180516         180517                    0.29                    1
# 180517         180518                    0.14                    1
# 180518         180519                    0.28                    1
#
#              sales  order_item_total  order_profit_per_order     order_status  \
# 0       299.980011        239.979996               88.790001           CLOSED
# 1       129.990005        107.889999               36.470001  PENDING_PAYMENT
# 2       250.000000        227.500000               68.250000  PENDING_PAYMENT
# 3       199.990005        193.990005               91.180000  PENDING_PAYMENT
# 4       199.919998        159.940002               33.590000           CLOSED
# ...            ...               ...                     ...              ...
# 180514  215.820007        161.869995             -107.959999       PROCESSING
# 180515  215.820007        172.660004             -126.559998         COMPLETE
# 180516  327.750000        314.640015               91.250000         COMPLETE
# 180517   11.540000         10.910000                1.530000  PENDING_PAYMENT
# 180518   39.750000         34.980000                9.790000           CLOSED
#
#         shipping_date_(dateorders)   shipping_mode  location_id
# 0              2015-01-03 00:00:00  Standard Class           58
# 1              2015-01-04 00:21:00  Standard Class           54
# 2              2015-01-04 00:21:00  Standard Class           54
# 3              2015-01-04 00:21:00  Standard Class           54
# 4              2015-01-06 01:03:00  Standard Class           54
# ...                            ...             ...          ...
# 180514         2018-02-06 22:14:00  Standard Class            1
# 180515         2018-02-02 22:35:00  Standard Class            1
# 180516         2018-02-03 22:56:00  Standard Class            1
# 180517         2018-02-04 23:17:00  Standard Class            1
# 180518         2018-02-01 11:38:00        Same Day          170
#
# [180519 rows x 26 columns]

# %%
# Replace 'output_path' with the desired output directory
output_path = r'~\Documents\GitHub\E-Commerce_SupplyChain_DataAnalysis\data\processed'

# Save each DataFrame to a separate CSV file
dim_location.to_csv(os.path.join(output_path, 'dim_location.csv'), index=False)
dim_customer.to_csv(os.path.join(output_path, 'dim_customer.csv'), index=False)
dim_category.to_csv(os.path.join(output_path, 'dim_category.csv'), index=False)
dim_department.to_csv(os.path.join(output_path, 'dim_department.csv'), index=False)
dim_product.to_csv(os.path.join(output_path, 'dim_product.csv'), index=False)
orders_fact.to_csv(os.path.join(output_path, 'orders_fact.csv'), index=False)
